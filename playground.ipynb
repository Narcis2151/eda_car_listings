# %%
import pickle
with open('./data/playwright_Ford_details.pkl', 'rb') as f:
    t = pickle.load(f)

# %%
t
# Out:
# [{'make': 'Ford',
#   'price': '€29,100',
#   'technical_details': {'Vehicle condition': 'Used vehicle, Accident-free',
#    'Category': 'SUV / Off-road Vehicle / Pickup Truck',
#    'Mileage': '119,900\xa0km',
#    'Cubic Capacity': '1,996\xa0ccm',
#    'Power': '156\xa0kW\xa0(212\xa0hp)',
#    'Drive type': 'Internal combustion engine',
#    'Fuel': 'Diesel',
#    'Number of Seats': '5',
#    'Door Count': '4/5',
#    'Transmission': 'Automatic',
#    'Emission Class': 'Euro6d',
#    'Emissions Sticker': '4 (Green)',
#    'First Registration': '04/2019',
#    'Number of Vehicle Owners': '1',
#    'HU': 'New',
#    'Climatisation': 'Automatic climatisation, 2 zones',
#    'Parking sensors': 'Front, Rear, Camera',
#    'Airbags': 'Front and Side and More Airbags',
#    'Colour (Manufacturer)': 'Iridium-Schwarz Metallic',
#    'Colour': 'Black Metallic',
#    'Interior Design': 'Part leather, Grey'},
#   'additional_details': ['ABS',
#    'Adaptive Cruise Control',
# ...
